# %%
import os
import os, sys
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn import Sequential
import torch.optim as optim
import voxelmorph as vxm
import neurite as ne
import scipy.ndimage

os.environ['VXM_BACKEND'] = 'pytorch'
# Out:
# backend:pytorch
# Pytorch

# %%
os.environ.get('VXM_BACKEND')
# Out:
# 'pytorch'

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda:0

# %%
E1 = 1000
E2 = 1000

# %%
# 画像を読み込み
x_train = np.load('Train_3D_256_256_128_FOV_norm_data.npz')['Train']
x_train = np.transpose(x_train, (3, 0, 1, 2))

# # 新しいボリュームのサイズ (各軸を半分にする)
# new_shape = tuple([dim // 2 for dim in x_train.shape[1:]])

# # サイズを半分に縮小
# x_train_resized = np.zeros((x_train.shape[0], *new_shape))  # 新しい形に合わせて初期化

# for i in range(x_train.shape[0]):
#     # 各画像を縮小
#     x_train_resized[i] = scipy.ndimage.zoom(x_train[i], (0.5, 0.5, 0.5), order=3)
# print('Resized train vol_shape:', x_train_resized.shape[1:])
# print('Resized train shape:', x_train_resized.shape)
# x_train = x_train_resized

# %%
import torch

def vxm_data_generator(x_data, batch_size):
    vol_shape = x_data.shape[1:]  # データ形状を取得
    ndims = len(vol_shape)
    
    zero_phi = np.zeros([batch_size, *vol_shape, ndims])
    
    while True:
        idx1 = np.random.randint(0, x_data.shape[0], size=batch_size)
        moving_images = x_data[idx1, ..., np.newaxis]
        idx2 = np.random.randint(0, x_data.shape[0], size=batch_size)
        fixed_images = x_data[idx2, ..., np.newaxis]

        # TensorFlowからPyTorchのデータ形式に変換
        moving_images = torch.tensor(moving_images).permute(0, 4, 1, 2, 3).float()
        fixed_images = torch.tensor(fixed_images).permute(0, 4, 1, 2, 3).float()

        # チャンネルを最初の次元に追加
        moving_images = moving_images.permute(0, 1, 2, 3, 4)  # チャンネルを最初の次元に移動
        fixed_images = fixed_images.permute(0, 1, 2, 3, 4)  # チャンネルを最初の次元に移動

        inputs = [moving_images, fixed_images]
        outputs = [fixed_images, zero_phi]

        yield (inputs, outputs)

# %%
train_generator = vxm_data_generator(x_train, batch_size=2)
in_sample, out_sample = next(train_generator)

# in_sampleとout_sampleの内容を確認する
print("Input Sample Shapes:")
print("Moving Images Shape:", in_sample[0].shape)
print("Fixed Images Shape:", in_sample[1].shape)

print("\nOutput Sample Shapes:")
print("Moved Images (Fixed) Shape:", out_sample[0].shape)
print("Zero Gradient Shape:", out_sample[1].shape)
# Out:
# Input Sample Shapes:
# Moving Images Shape: torch.Size([2, 1, 128, 256, 256])
# Fixed Images Shape: torch.Size([2, 1, 128, 256, 256])
#
# Output Sample Shapes:
# Moved Images (Fixed) Shape: torch.Size([2, 1, 128, 256, 256])
# Zero Gradient Shape: (2, 128, 256, 256, 3)

# %%
mse_loss = vxm.losses.MSE().loss
grad_loss = vxm.losses.Grad('l2').loss

def total_loss(y_true, y_pred):
    mse = mse_loss(y_true, y_pred)
    grad = grad_loss(y_true, y_pred)
    return mse + 0.01 * grad, mse, grad
#     return mse_loss(y_true, y_pred)

def MSE_Loss(y_true, y_pred):
    mse = mse_loss(y_true, y_pred)
    return mse

# %%
# configure unet input shape (concatenation of moving and fixed images)
ndim = 3
unet_input_features = 2
# inshape = (*x_train.shape[1:], unet_input_features)

nb_features = [
    [32, 64, 64, 64, 64],
    [64, 64, 64, 64, 64, 32, 16, 16]
]

# %%
model3D_3 = vxm.networks.VxmDense((128, 256, 256), nb_features, int_steps=0)
model3D_3.to(device)
optimizer = optim.Adam(model3D_3.parameters(), lr=1e-4)
# Out:
# 5
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# 64
# 128
# 8
# 9
# 64
# 10
# 8
# 9
# 64
# 10
# 8
# 9
# 64
# 10
# 8
# 9
# 64
# 10
# 8
# 9
# 64
# 10
# 11
# 11
# 11
# [64, 128, 128]
# C:\Users\user\anaconda3\envs\nn\lib\site-packages\torch\functional.py:507: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\TensorShape.cpp:3550.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
# # decoderHight
# from tqdm.notebook import tqdm
# transformer = vxm.layers.SpatialTransformer((64, 128, 128)).to(device)

# # 3D ガウシアンフィルタを適用する関数
# def gaussian_smooth_3d(tensor, kernel_size=5, sigma=1.0):
#     """ 3D ガウシアンフィルタで displacement field をスムージング """
#     # 3D Gaussian Kernel の作成
#     from scipy.ndimage import gaussian_filter
#     tensor_np = tensor.cpu().numpy()
#     smoothed_np = gaussian_filter(tensor_np, sigma=[0, 0, sigma, sigma, sigma])  # チャネル方向にはフィルタ適用しない
#     return torch.tensor(smoothed_np, dtype=torch.float32, device=tensor.device)


# # エポック数と最小ロスの設定
# epochs = 50000
# best_loss = float('inf')
# shift_range = 1

# # ロスや他のメトリクスを記録するリスト
# losses = []
# loss_vecs = []
# loss_images = []
# loss_hightVecs = []
# for epoch in tqdm(range(epochs)):
#     # 100エポックごとにshift_rangeを増やす
#     if epoch % 1000 == 0 and epoch > 0:
#         shift_range += 1
#         print(f"Epoch {epoch}: Increasing shift range to ±{shift_range} pixels.")

#     # 学習データのバッチを取得
#     train_batch, _ = next(train_generator)
#     moving_images = torch.tensor(train_batch[0], dtype=torch.float32).to(device)

#     # 画像サイズを設定
#     B, D, H, W = 2, 8, 16, 16  # バッチサイズと画像の次元

#     # displacement_field をボクセルごとにランダムに作成
#     displacement_field = (torch.rand((B, 3, D, H, W), dtype=torch.float32) * 2 - 1) * shift_range
#     displacement_field = displacement_field.to(device)

#     # 3D Gaussian Smoothing を適用
#     displacement_field = gaussian_smooth_3d(displacement_field, sigma=2.0)
#     displacement_field = torch.nn.functional.interpolate(displacement_field, size=(64,128,128), mode='trilinear', align_corners=False)

#     # 位置をずらした画像を生成
#     moving_images2 = transformer(moving_images, displacement_field)

#     # 勾配を初期化
#     optimizer.zero_grad()

#     # 順伝播
#     transformed_image, Vec, Vec_HH, moving_image_HH = model3D_3(moving_images, moving_images2)

#     # 損失を計算
#     loss_vec = MSE_Loss(displacement_field, Vec) * 0.1
#     # loss_vec = MSE_Loss(displacement_field, Vec) 
#     loss_image = MSE_Loss(moving_images2, transformed_image) * 100
    
#     displacement_field = displacement_field.cpu()
#     moving_image_HH = moving_image_HH.cpu()
#     Vec_HH = Vec_HH.cpu()

#     moving_image_HH = np.abs(moving_image_HH)
#     threshold = 0.05
#     moving_image_HH = (moving_image_HH >= threshold).to(torch.uint8)
#     hightVec = displacement_field * moving_image_HH
#     loss_hightVec =MSE_Loss(hightVec, Vec_HH)
    
#     loss = loss_vec + loss_image + loss_hightVec

#     # 逆伝播
#     loss.backward()
#     optimizer.step()

#     # モデルを保存
#     torch.save(model3D_3.state_dict(), 'model_VXM_3D_duwl_omomi_decoderHH.pth')

#     # エポックごとのロスを保存
#     losses.append(loss.cpu().item())
#     loss_vecs.append(loss_vec.cpu().item())
#     loss_images.append(loss_image.cpu().item())
#     loss_hightVecs.append(loss_hightVec.cpu().item())
   
#     # エポックごとのロスの表示
#     print(f"Epoch {epoch+1}/{epochs}, Loss: {loss:.4f}, loss_vec: {loss_vec:.4f}, loss_image: {loss_image:.4f}, loss_hightVec: {loss_hightVec:.4f}, Shift Range: ±{shift_range} pixels")

# %%
# NotdecoderHight
from tqdm.notebook import tqdm
transformer = vxm.layers.SpatialTransformer((128, 256, 256)).to(device)

# 3D ガウシアンフィルタを適用する関数
def gaussian_smooth_3d(tensor, kernel_size=5, sigma=1.0):
    """ 3D ガウシアンフィルタで displacement field をスムージング """
    # 3D Gaussian Kernel の作成
    from scipy.ndimage import gaussian_filter
    tensor_np = tensor.cpu().numpy()
    smoothed_np = gaussian_filter(tensor_np, sigma=[0, 0, sigma, sigma, sigma])  # チャネル方向にはフィルタ適用しない
    return torch.tensor(smoothed_np, dtype=torch.float32, device=tensor.device)


# エポック数と最小ロスの設定
#epochs = 50000
epochs = 1000
best_loss = float('inf')
shift_range = 1

# ロスや他のメトリクスを記録するリスト
losses = []
loss_vecs = []
loss_images = []
loss_hightVecs = []
for epoch in tqdm(range(epochs)):
    # 100エポックごとにshift_rangeを増やす
 #   if epoch % 1000 == 0 and epoch > 0:
    if epoch % 100 == 0 and epoch > 0:
        shift_range += 5
        print(f"Epoch {epoch}: Increasing shift range to ±{shift_range} pixels.")

    # 学習データのバッチを取得
    train_batch, _ = next(train_generator)
    moving_images = torch.tensor(train_batch[0], dtype=torch.float32).to(device)

    # 画像サイズを設定
    B, D, H, W = 2, 8, 16, 16  # バッチサイズと画像の次元

    # displacement_field をボクセルごとにランダムに作成
    displacement_field = (torch.rand((B, 3, D, H, W), dtype=torch.float32) * 2 - 1) * shift_range
    displacement_field = displacement_field.to(device)

    # 3D Gaussian Smoothing を適用
    displacement_field = gaussian_smooth_3d(displacement_field, sigma=2.0)
    displacement_field = torch.nn.functional.interpolate(displacement_field, size=(128,256,256), mode='trilinear', align_corners=False)

    # 位置をずらした画像を生成
    moving_images2 = transformer(moving_images, displacement_field)

    # 勾配を初期化
    optimizer.zero_grad()

    # 順伝播
    transformed_image, Vec = model3D_3(moving_images, moving_images2)

    # 損失を計算
    loss_vec = MSE_Loss(displacement_field, Vec) * 0.1
    loss_image = MSE_Loss(moving_images2, transformed_image) * 100
    
    loss = loss_vec + loss_image

    # 逆伝播
    loss.backward()
    optimizer.step()

    # モデルを保存
    torch.save(model3D_3.state_dict(), 'model_VXM_3D_duwl_omomi_NodecoderHH_256.pth')

    # エポックごとのロスを保存
    losses.append(loss.cpu().item())
    loss_vecs.append(loss_vec.cpu().item())
    loss_images.append(loss_image.cpu().item())
    # loss_hightVecs.append(loss_hightVec.cpu().item())
   
    # エポックごとのロスの表示
    print(f"Epoch {epoch+1}/{epochs}, Loss: {loss:.4f}, loss_vec: {loss_vec:.4f}, loss_image: {loss_image:.4f}, Shift Range: ±{shift_range} pixels")
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# C:\Users\user\AppData\Local\Temp\ipykernel_13700\1348354774.py:35: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   moving_images = torch.tensor(train_batch[0], dtype=torch.float32).to(device)
# LL_Moving tensor(0.2219, device='cuda:0')
# HH_Moving tensor(0.0104, device='cuda:0')
# LL_Fixed tensor(0.2218, device='cuda:0')
# HH_Fixed tensor(0.0098, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 1/1000, Loss: 0.0011, loss_vec: 0.0002, loss_image: 0.0009, Shift Range: ±1 pixels
# LL_Moving tensor(0.2101, device='cuda:0')
# HH_Moving tensor(0.0109, device='cuda:0')
# LL_Fixed tensor(0.2100, device='cuda:0')
# HH_Fixed tensor(0.0103, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 2/1000, Loss: 0.0011, loss_vec: 0.0002, loss_image: 0.0009, Shift Range: ±1 pixels
# LL_Moving tensor(0.1866, device='cuda:0')
# HH_Moving tensor(0.0100, device='cuda:0')
# LL_Fixed tensor(0.1865, device='cuda:0')
# HH_Fixed tensor(0.0095, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 3/1000, Loss: 0.0011, loss_vec: 0.0002, loss_image: 0.0009, Shift Range: ±1 pixels
# LL_Moving tensor(0.1944, device='cuda:0')
# HH_Moving tensor(0.0103, device='cuda:0')
# LL_Fixed tensor(0.1944, device='cuda:0')
# HH_Fixed tensor(0.0098, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 4/1000, Loss: 0.0009, loss_vec: 0.0002, loss_image: 0.0007, Shift Range: ±1 pixels
# LL_Moving tensor(0.2417, device='cuda:0')
# HH_Moving tensor(0.0125, device='cuda:0')
# LL_Fixed tensor(0.2416, device='cuda:0')
# HH_Fixed tensor(0.0119, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 5/1000, Loss: 0.0010, loss_vec: 0.0002, loss_image: 0.0008, Shift Range: ±1 pixels
# LL_Moving tensor(0.2053, device='cuda:0')
# HH_Moving tensor(0.0089, device='cuda:0')
# LL_Fixed tensor(0.2052, device='cuda:0')
# HH_Fixed tensor(0.0084, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 6/1000, Loss: 0.0007, loss_vec: 0.0002, loss_image: 0.0006, Shift Range: ±1 pixels
# LL_Moving tensor(0.2209, device='cuda:0')
# HH_Moving tensor(0.0105, device='cuda:0')
# LL_Fixed tensor(0.2209, device='cuda:0')
# HH_Fixed tensor(0.0099, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 7/1000, Loss: 0.0008, loss_vec: 0.0002, loss_image: 0.0006, Shift Range: ±1 pixels
# LL_Moving tensor(0.2419, device='cuda:0')
# HH_Moving tensor(0.0130, device='cuda:0')
# LL_Fixed tensor(0.2418, device='cuda:0')
# HH_Fixed tensor(0.0123, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 8/1000, Loss: 0.0009, loss_vec: 0.0002, loss_image: 0.0007, Shift Range: ±1 pixels
# LL_Moving tensor(0.2120, device='cuda:0')
# HH_Moving tensor(0.0113, device='cuda:0')
# LL_Fixed tensor(0.2120, device='cuda:0')
# HH_Fixed tensor(0.0106, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 9/1000, Loss: 0.0010, loss_vec: 0.0002, loss_image: 0.0008, Shift Range: ±1 pixels
# LL_Moving tensor(0.2261, device='cuda:0')
# HH_Moving tensor(0.0111, device='cuda:0')
# LL_Fixed tensor(0.2260, device='cuda:0')
# HH_Fixed tensor(0.0104, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 10/1000, Loss: 0.0012, loss_vec: 0.0003, loss_image: 0.0009, Shift Range: ±1 pixels
# LL_Moving tensor(0.2021, device='cuda:0')
# HH_Moving tensor(0.0105, device='cuda:0')
# LL_Fixed tensor(0.2020, device='cuda:0')
# HH_Fixed tensor(0.0099, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 11/1000, Loss: 0.0013, loss_vec: 0.0003, loss_image: 0.0010, Shift Range: ±1 pixels
# LL_Moving tensor(0.1578, device='cuda:0')
# HH_Moving tensor(0.0083, device='cuda:0')
# LL_Fixed tensor(0.1578, device='cuda:0')
# HH_Fixed tensor(0.0078, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 12/1000, Loss: 0.0005, loss_vec: 0.0002, loss_image: 0.0003, Shift Range: ±1 pixels
# LL_Moving tensor(0.2262, device='cuda:0')
# HH_Moving tensor(0.0095, device='cuda:0')
# LL_Fixed tensor(0.2262, device='cuda:0')
# HH_Fixed tensor(0.0090, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 13/1000, Loss: 0.0007, loss_vec: 0.0002, loss_image: 0.0006, Shift Range: ±1 pixels
# LL_Moving tensor(0.1926, device='cuda:0')
# HH_Moving tensor(0.0099, device='cuda:0')
# LL_Fixed tensor(0.1924, device='cuda:0')
# HH_Fixed tensor(0.0094, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 14/1000, Loss: 0.0010, loss_vec: 0.0002, loss_image: 0.0008, Shift Range: ±1 pixels
# LL_Moving tensor(0.2246, device='cuda:0')
# HH_Moving tensor(0.0122, device='cuda:0')
# LL_Fixed tensor(0.2245, device='cuda:0')
# HH_Fixed tensor(0.0115, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 15/1000, Loss: 0.0009, loss_vec: 0.0002, loss_image: 0.0007, Shift Range: ±1 pixels
# LL_Moving tensor(0.1820, device='cuda:0')
# HH_Moving tensor(0.0084, device='cuda:0')
# LL_Fixed tensor(0.1820, device='cuda:0')
# HH_Fixed tensor(0.0079, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 16/1000, Loss: 0.0005, loss_vec: 0.0002, loss_image: 0.0004, Shift Range: ±1 pixels
# LL_Moving tensor(0.2191, device='cuda:0')
# HH_Moving tensor(0.0097, device='cuda:0')
# LL_Fixed tensor(0.2190, device='cuda:0')
# HH_Fixed tensor(0.0092, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 17/1000, Loss: 0.0007, loss_vec: 0.0002, loss_image: 0.0005, Shift Range: ±1 pixels
# LL_Moving tensor(0.2545, device='cuda:0')
# HH_Moving tensor(0.0127, device='cuda:0')
# LL_Fixed tensor(0.2544, device='cuda:0')
# HH_Fixed tensor(0.0120, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 18/1000, Loss: 0.0008, loss_vec: 0.0002, loss_image: 0.0006, Shift Range: ±1 pixels
# LL_Moving tensor(0.1905, device='cuda:0')
# HH_Moving tensor(0.0100, device='cuda:0')
# LL_Fixed tensor(0.1904, device='cuda:0')
# HH_Fixed tensor(0.0095, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 19/1000, Loss: 0.0009, loss_vec: 0.0002, loss_image: 0.0007, Shift Range: ±1 pixels
# LL_Moving tensor(0.2205, device='cuda:0')
# HH_Moving tensor(0.0109, device='cuda:0')
# LL_Fixed tensor(0.2204, device='cuda:0')
# HH_Fixed tensor(0.0102, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 20/1000, Loss: 0.0012, loss_vec: 0.0002, loss_image: 0.0009, Shift Range: ±1 pixels
# LL_Moving tensor(0.1527, device='cuda:0')
# HH_Moving tensor(0.0080, device='cuda:0')
# LL_Fixed tensor(0.1526, device='cuda:0')
# HH_Fixed tensor(0.0076, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 21/1000, Loss: 0.0005, loss_vec: 0.0002, loss_image: 0.0003, Shift Range: ±1 pixels
# LL_Moving tensor(0.2503, device='cuda:0')
# HH_Moving tensor(0.0111, device='cuda:0')
# LL_Fixed tensor(0.2502, device='cuda:0')
# HH_Fixed tensor(0.0104, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 22/1000, Loss: 0.0009, loss_vec: 0.0002, loss_image: 0.0007, Shift Range: ±1 pixels
# LL_Moving tensor(0.2008, device='cuda:0')
# HH_Moving tensor(0.0101, device='cuda:0')
# LL_Fixed tensor(0.2006, device='cuda:0')
# HH_Fixed tensor(0.0095, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 23/1000, Loss: 0.0008, loss_vec: 0.0002, loss_image: 0.0006, Shift Range: ±1 pixels
# LL_Moving tensor(0.1910, device='cuda:0')
# HH_Moving tensor(0.0088, device='cuda:0')
# LL_Fixed tensor(0.1909, device='cuda:0')
# HH_Fixed tensor(0.0083, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 24/1000, Loss: 0.0009, loss_vec: 0.0002, loss_image: 0.0006, Shift Range: ±1 pixels
# LL_Moving tensor(0.2287, device='cuda:0')
# HH_Moving tensor(0.0113, device='cuda:0')
# LL_Fixed tensor(0.2286, device='cuda:0')
# HH_Fixed tensor(0.0106, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 25/1000, Loss: 0.0007, loss_vec: 0.0002, loss_image: 0.0005, Shift Range: ±1 pixels
# LL_Moving tensor(0.1490, device='cuda:0')
# HH_Moving tensor(0.0087, device='cuda:0')
# LL_Fixed tensor(0.1489, device='cuda:0')
# HH_Fixed tensor(0.0082, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 26/1000, Loss: 0.0008, loss_vec: 0.0002, loss_image: 0.0005, Shift Range: ±1 pixels
# LL_Moving tensor(0.2165, device='cuda:0')
# HH_Moving tensor(0.0105, device='cuda:0')
# LL_Fixed tensor(0.2165, device='cuda:0')
# HH_Fixed tensor(0.0098, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 27/1000, Loss: 0.0014, loss_vec: 0.0002, loss_image: 0.0011, Shift Range: ±1 pixels
# LL_Moving tensor(0.2189, device='cuda:0')
# HH_Moving tensor(0.0101, device='cuda:0')
# LL_Fixed tensor(0.2189, device='cuda:0')
# HH_Fixed tensor(0.0095, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 28/1000, Loss: 0.0012, loss_vec: 0.0002, loss_image: 0.0009, Shift Range: ±1 pixels
# LL_Moving tensor(0.2121, device='cuda:0')
# HH_Moving tensor(0.0103, device='cuda:0')
# LL_Fixed tensor(0.2121, device='cuda:0')
# HH_Fixed tensor(0.0097, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 29/1000, Loss: 0.0007, loss_vec: 0.0002, loss_image: 0.0005, Shift Range: ±1 pixels
# LL_Moving tensor(0.1873, device='cuda:0')
# HH_Moving tensor(0.0088, device='cuda:0')
# LL_Fixed tensor(0.1872, device='cuda:0')
# HH_Fixed tensor(0.0082, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 30/1000, Loss: 0.0007, loss_vec: 0.0002, loss_image: 0.0005, Shift Range: ±1 pixels
# LL_Moving tensor(0.1995, device='cuda:0')
# HH_Moving tensor(0.0099, device='cuda:0')
# LL_Fixed tensor(0.1995, device='cuda:0')
# HH_Fixed tensor(0.0093, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 31/1000, Loss: 0.0009, loss_vec: 0.0002, loss_image: 0.0007, Shift Range: ±1 pixels
# LL_Moving tensor(0.2246, device='cuda:0')
# HH_Moving tensor(0.0122, device='cuda:0')
# LL_Fixed tensor(0.2245, device='cuda:0')
# HH_Fixed tensor(0.0115, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 32/1000, Loss: 0.0011, loss_vec: 0.0002, loss_image: 0.0009, Shift Range: ±1 pixels
# LL_Moving tensor(0.2018, device='cuda:0')
# HH_Moving tensor(0.0098, device='cuda:0')
# LL_Fixed tensor(0.2017, device='cuda:0')
# HH_Fixed tensor(0.0092, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 33/1000, Loss: 0.0009, loss_vec: 0.0002, loss_image: 0.0007, Shift Range: ±1 pixels
# LL_Moving tensor(0.1875, device='cuda:0')
# HH_Moving tensor(0.0103, device='cuda:0')
# LL_Fixed tensor(0.1875, device='cuda:0')
# HH_Fixed tensor(0.0096, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 34/1000, Loss: 0.0010, loss_vec: 0.0002, loss_image: 0.0007, Shift Range: ±1 pixels
# LL_Moving tensor(0.2381, device='cuda:0')
# HH_Moving tensor(0.0126, device='cuda:0')
# LL_Fixed tensor(0.2380, device='cuda:0')
# HH_Fixed tensor(0.0118, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 35/1000, Loss: 0.0009, loss_vec: 0.0002, loss_image: 0.0007, Shift Range: ±1 pixels
# LL_Moving tensor(0.1768, device='cuda:0')
# HH_Moving tensor(0.0087, device='cuda:0')
# LL_Fixed tensor(0.1768, device='cuda:0')
# HH_Fixed tensor(0.0083, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 36/1000, Loss: 0.0007, loss_vec: 0.0002, loss_image: 0.0005, Shift Range: ±1 pixels
# LL_Moving tensor(0.2471, device='cuda:0')
# HH_Moving tensor(0.0122, device='cuda:0')
# LL_Fixed tensor(0.2470, device='cuda:0')
# HH_Fixed tensor(0.0115, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 37/1000, Loss: 0.0009, loss_vec: 0.0002, loss_image: 0.0007, Shift Range: ±1 pixels
# LL_Moving tensor(0.2396, device='cuda:0')
# HH_Moving tensor(0.0118, device='cuda:0')
# LL_Fixed tensor(0.2394, device='cuda:0')
# HH_Fixed tensor(0.0110, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 38/1000, Loss: 0.0010, loss_vec: 0.0002, loss_image: 0.0008, Shift Range: ±1 pixels
# LL_Moving tensor(0.2070, device='cuda:0')
# HH_Moving tensor(0.0096, device='cuda:0')
# LL_Fixed tensor(0.2069, device='cuda:0')
# HH_Fixed tensor(0.0091, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 39/1000, Loss: 0.0008, loss_vec: 0.0002, loss_image: 0.0006, Shift Range: ±1 pixels
# LL_Moving tensor(0.2105, device='cuda:0')
# HH_Moving tensor(0.0110, device='cuda:0')
# LL_Fixed tensor(0.2105, device='cuda:0')
# HH_Fixed tensor(0.0105, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 40/1000, Loss: 0.0007, loss_vec: 0.0002, loss_image: 0.0005, Shift Range: ±1 pixels
# LL_Moving tensor(0.2121, device='cuda:0')
# HH_Moving tensor(0.0101, device='cuda:0')
# LL_Fixed tensor(0.2120, device='cuda:0')
# HH_Fixed tensor(0.0095, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 41/1000, Loss: 0.0008, loss_vec: 0.0002, loss_image: 0.0006, Shift Range: ±1 pixels
# LL_Moving tensor(0.2055, device='cuda:0')
# HH_Moving tensor(0.0105, device='cuda:0')
# LL_Fixed tensor(0.2054, device='cuda:0')
# HH_Fixed tensor(0.0099, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 42/1000, Loss: 0.0008, loss_vec: 0.0002, loss_image: 0.0007, Shift Range: ±1 pixels
# LL_Moving tensor(0.2559, device='cuda:0')
# HH_Moving tensor(0.0121, device='cuda:0')
# LL_Fixed tensor(0.2559, device='cuda:0')
# HH_Fixed tensor(0.0114, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 43/1000, Loss: 0.0012, loss_vec: 0.0002, loss_image: 0.0010, Shift Range: ±1 pixels
# LL_Moving tensor(0.1927, device='cuda:0')
# HH_Moving tensor(0.0088, device='cuda:0')
# LL_Fixed tensor(0.1927, device='cuda:0')
# HH_Fixed tensor(0.0083, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 44/1000, Loss: 0.0006, loss_vec: 0.0002, loss_image: 0.0004, Shift Range: ±1 pixels
# LL_Moving tensor(0.1959, device='cuda:0')
# HH_Moving tensor(0.0102, device='cuda:0')
# LL_Fixed tensor(0.1958, device='cuda:0')
# HH_Fixed tensor(0.0097, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 45/1000, Loss: 0.0008, loss_vec: 0.0002, loss_image: 0.0006, Shift Range: ±1 pixels
# LL_Moving tensor(0.1899, device='cuda:0')
# HH_Moving tensor(0.0095, device='cuda:0')
# LL_Fixed tensor(0.1898, device='cuda:0')
# HH_Fixed tensor(0.0089, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 46/1000, Loss: 0.0015, loss_vec: 0.0003, loss_image: 0.0012, Shift Range: ±1 pixels
# LL_Moving tensor(0.1699, device='cuda:0')
# HH_Moving tensor(0.0085, device='cuda:0')
# LL_Fixed tensor(0.1698, device='cuda:0')
# HH_Fixed tensor(0.0080, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 47/1000, Loss: 0.0007, loss_vec: 0.0003, loss_image: 0.0004, Shift Range: ±1 pixels
# LL_Moving tensor(0.1925, device='cuda:0')
# HH_Moving tensor(0.0094, device='cuda:0')
# LL_Fixed tensor(0.1924, device='cuda:0')
# HH_Fixed tensor(0.0089, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 48/1000, Loss: 0.0008, loss_vec: 0.0002, loss_image: 0.0006, Shift Range: ±1 pixels
# LL_Moving tensor(0.1781, device='cuda:0')
# HH_Moving tensor(0.0092, device='cuda:0')
# LL_Fixed tensor(0.1780, device='cuda:0')
# HH_Fixed tensor(0.0087, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 49/1000, Loss: 0.0007, loss_vec: 0.0002, loss_image: 0.0005, Shift Range: ±1 pixels
# LL_Moving tensor(0.2698, device='cuda:0')
# HH_Moving tensor(0.0121, device='cuda:0')
# LL_Fixed tensor(0.2699, device='cuda:0')
# HH_Fixed tensor(0.0112, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 50/1000, Loss: 0.0010, loss_vec: 0.0002, loss_image: 0.0008, Shift Range: ±1 pixels
# LL_Moving tensor(0.2758, device='cuda:0')
# HH_Moving tensor(0.0134, device='cuda:0')
# LL_Fixed tensor(0.2757, device='cuda:0')
# HH_Fixed tensor(0.0126, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 51/1000, Loss: 0.0011, loss_vec: 0.0002, loss_image: 0.0009, Shift Range: ±1 pixels
# LL_Moving tensor(0.2719, device='cuda:0')
# HH_Moving tensor(0.0128, device='cuda:0')
# LL_Fixed tensor(0.2717, device='cuda:0')
# HH_Fixed tensor(0.0120, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 52/1000, Loss: 0.0011, loss_vec: 0.0002, loss_image: 0.0009, Shift Range: ±1 pixels
# LL_Moving tensor(0.1916, device='cuda:0')
# HH_Moving tensor(0.0102, device='cuda:0')
# LL_Fixed tensor(0.1915, device='cuda:0')
# HH_Fixed tensor(0.0096, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 53/1000, Loss: 0.0009, loss_vec: 0.0002, loss_image: 0.0006, Shift Range: ±1 pixels
# LL_Moving tensor(0.2044, device='cuda:0')
# HH_Moving tensor(0.0090, device='cuda:0')
# LL_Fixed tensor(0.2043, device='cuda:0')
# HH_Fixed tensor(0.0085, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 54/1000, Loss: 0.0010, loss_vec: 0.0003, loss_image: 0.0007, Shift Range: ±1 pixels
# LL_Moving tensor(0.1876, device='cuda:0')
# HH_Moving tensor(0.0098, device='cuda:0')
# LL_Fixed tensor(0.1876, device='cuda:0')
# HH_Fixed tensor(0.0093, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 55/1000, Loss: 0.0010, loss_vec: 0.0002, loss_image: 0.0007, Shift Range: ±1 pixels
# LL_Moving tensor(0.1960, device='cuda:0')
# HH_Moving tensor(0.0110, device='cuda:0')
# LL_Fixed tensor(0.1959, device='cuda:0')
# HH_Fixed tensor(0.0104, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 56/1000, Loss: 0.0011, loss_vec: 0.0002, loss_image: 0.0009, Shift Range: ±1 pixels
# LL_Moving tensor(0.2334, device='cuda:0')
# HH_Moving tensor(0.0117, device='cuda:0')
# LL_Fixed tensor(0.2334, device='cuda:0')
# HH_Fixed tensor(0.0110, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 57/1000, Loss: 0.0010, loss_vec: 0.0002, loss_image: 0.0008, Shift Range: ±1 pixels
# LL_Moving tensor(0.2381, device='cuda:0')
# HH_Moving tensor(0.0126, device='cuda:0')
# LL_Fixed tensor(0.2379, device='cuda:0')
# HH_Fixed tensor(0.0119, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 58/1000, Loss: 0.0007, loss_vec: 0.0002, loss_image: 0.0005, Shift Range: ±1 pixels
# LL_Moving tensor(0.2334, device='cuda:0')
# HH_Moving tensor(0.0114, device='cuda:0')
# LL_Fixed tensor(0.2333, device='cuda:0')
# HH_Fixed tensor(0.0105, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 59/1000, Loss: 0.0011, loss_vec: 0.0002, loss_image: 0.0009, Shift Range: ±1 pixels
# LL_Moving tensor(0.2083, device='cuda:0')
# HH_Moving tensor(0.0114, device='cuda:0')
# LL_Fixed tensor(0.2083, device='cuda:0')
# HH_Fixed tensor(0.0108, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 60/1000, Loss: 0.0008, loss_vec: 0.0002, loss_image: 0.0006, Shift Range: ±1 pixels
# LL_Moving tensor(0.2174, device='cuda:0')
# HH_Moving tensor(0.0110, device='cuda:0')
# LL_Fixed tensor(0.2173, device='cuda:0')
# HH_Fixed tensor(0.0104, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 61/1000, Loss: 0.0009, loss_vec: 0.0002, loss_image: 0.0007, Shift Range: ±1 pixels
# LL_Moving tensor(0.1601, device='cuda:0')
# HH_Moving tensor(0.0087, device='cuda:0')
# LL_Fixed tensor(0.1601, device='cuda:0')
# HH_Fixed tensor(0.0082, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 62/1000, Loss: 0.0008, loss_vec: 0.0002, loss_image: 0.0006, Shift Range: ±1 pixels
# LL_Moving tensor(0.1677, device='cuda:0')
# HH_Moving tensor(0.0081, device='cuda:0')
# LL_Fixed tensor(0.1677, device='cuda:0')
# HH_Fixed tensor(0.0077, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 63/1000, Loss: 0.0009, loss_vec: 0.0002, loss_image: 0.0006, Shift Range: ±1 pixels
# LL_Moving tensor(0.2148, device='cuda:0')
# HH_Moving tensor(0.0102, device='cuda:0')
# LL_Fixed tensor(0.2148, device='cuda:0')
# HH_Fixed tensor(0.0095, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 64/1000, Loss: 0.0007, loss_vec: 0.0002, loss_image: 0.0005, Shift Range: ±1 pixels
# LL_Moving tensor(0.1909, device='cuda:0')
# HH_Moving tensor(0.0083, device='cuda:0')
# LL_Fixed tensor(0.1909, device='cuda:0')
# HH_Fixed tensor(0.0079, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 65/1000, Loss: 0.0006, loss_vec: 0.0002, loss_image: 0.0004, Shift Range: ±1 pixels
# LL_Moving tensor(0.1934, device='cuda:0')
# HH_Moving tensor(0.0103, device='cuda:0')
# LL_Fixed tensor(0.1932, device='cuda:0')
# HH_Fixed tensor(0.0096, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 66/1000, Loss: 0.0011, loss_vec: 0.0002, loss_image: 0.0009, Shift Range: ±1 pixels
# LL_Moving tensor(0.2138, device='cuda:0')
# HH_Moving tensor(0.0097, device='cuda:0')
# LL_Fixed tensor(0.2137, device='cuda:0')
# HH_Fixed tensor(0.0092, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 67/1000, Loss: 0.0008, loss_vec: 0.0002, loss_image: 0.0005, Shift Range: ±1 pixels
# LL_Moving tensor(0.2223, device='cuda:0')
# HH_Moving tensor(0.0115, device='cuda:0')
# LL_Fixed tensor(0.2222, device='cuda:0')
# HH_Fixed tensor(0.0110, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 68/1000, Loss: 0.0008, loss_vec: 0.0002, loss_image: 0.0006, Shift Range: ±1 pixels
# LL_Moving tensor(0.2334, device='cuda:0')
# HH_Moving tensor(0.0118, device='cuda:0')
# LL_Fixed tensor(0.2333, device='cuda:0')
# HH_Fixed tensor(0.0112, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 69/1000, Loss: 0.0010, loss_vec: 0.0002, loss_image: 0.0007, Shift Range: ±1 pixels
# LL_Moving tensor(0.2669, device='cuda:0')
# HH_Moving tensor(0.0142, device='cuda:0')
# LL_Fixed tensor(0.2668, device='cuda:0')
# HH_Fixed tensor(0.0134, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 70/1000, Loss: 0.0009, loss_vec: 0.0002, loss_image: 0.0007, Shift Range: ±1 pixels
# LL_Moving tensor(0.2063, device='cuda:0')
# HH_Moving tensor(0.0089, device='cuda:0')
# LL_Fixed tensor(0.2063, device='cuda:0')
# HH_Fixed tensor(0.0084, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 71/1000, Loss: 0.0007, loss_vec: 0.0002, loss_image: 0.0005, Shift Range: ±1 pixels
# LL_Moving tensor(0.1477, device='cuda:0')
# HH_Moving tensor(0.0082, device='cuda:0')
# LL_Fixed tensor(0.1477, device='cuda:0')
# HH_Fixed tensor(0.0078, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 72/1000, Loss: 0.0004, loss_vec: 0.0002, loss_image: 0.0003, Shift Range: ±1 pixels
# LL_Moving tensor(0.1902, device='cuda:0')
# HH_Moving tensor(0.0091, device='cuda:0')
# LL_Fixed tensor(0.1901, device='cuda:0')
# HH_Fixed tensor(0.0086, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 73/1000, Loss: 0.0008, loss_vec: 0.0002, loss_image: 0.0006, Shift Range: ±1 pixels
# LL_Moving tensor(0.1982, device='cuda:0')
# HH_Moving tensor(0.0082, device='cuda:0')
# LL_Fixed tensor(0.1982, device='cuda:0')
# HH_Fixed tensor(0.0077, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 74/1000, Loss: 0.0008, loss_vec: 0.0002, loss_image: 0.0006, Shift Range: ±1 pixels
# LL_Moving tensor(0.1994, device='cuda:0')
# HH_Moving tensor(0.0103, device='cuda:0')
# LL_Fixed tensor(0.1993, device='cuda:0')
# HH_Fixed tensor(0.0097, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 75/1000, Loss: 0.0008, loss_vec: 0.0002, loss_image: 0.0006, Shift Range: ±1 pixels
# LL_Moving tensor(0.1901, device='cuda:0')
# HH_Moving tensor(0.0097, device='cuda:0')
# LL_Fixed tensor(0.1900, device='cuda:0')
# HH_Fixed tensor(0.0091, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 76/1000, Loss: 0.0009, loss_vec: 0.0002, loss_image: 0.0007, Shift Range: ±1 pixels
# LL_Moving tensor(0.2147, device='cuda:0')
# HH_Moving tensor(0.0099, device='cuda:0')
# LL_Fixed tensor(0.2147, device='cuda:0')
# HH_Fixed tensor(0.0093, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 77/1000, Loss: 0.0009, loss_vec: 0.0002, loss_image: 0.0006, Shift Range: ±1 pixels
# LL_Moving tensor(0.2236, device='cuda:0')
# HH_Moving tensor(0.0118, device='cuda:0')
# LL_Fixed tensor(0.2235, device='cuda:0')
# HH_Fixed tensor(0.0111, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 78/1000, Loss: 0.0012, loss_vec: 0.0002, loss_image: 0.0010, Shift Range: ±1 pixels
# LL_Moving tensor(0.1819, device='cuda:0')
# HH_Moving tensor(0.0084, device='cuda:0')
# LL_Fixed tensor(0.1818, device='cuda:0')
# HH_Fixed tensor(0.0079, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 79/1000, Loss: 0.0008, loss_vec: 0.0002, loss_image: 0.0006, Shift Range: ±1 pixels
# LL_Moving tensor(0.1490, device='cuda:0')
# HH_Moving tensor(0.0087, device='cuda:0')
# LL_Fixed tensor(0.1489, device='cuda:0')
# HH_Fixed tensor(0.0082, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 80/1000, Loss: 0.0008, loss_vec: 0.0002, loss_image: 0.0006, Shift Range: ±1 pixels
# LL_Moving tensor(0.1915, device='cuda:0')
# HH_Moving tensor(0.0100, device='cuda:0')
# LL_Fixed tensor(0.1914, device='cuda:0')
# HH_Fixed tensor(0.0094, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 81/1000, Loss: 0.0011, loss_vec: 0.0002, loss_image: 0.0009, Shift Range: ±1 pixels
# LL_Moving tensor(0.1827, device='cuda:0')
# HH_Moving tensor(0.0097, device='cuda:0')
# LL_Fixed tensor(0.1826, device='cuda:0')
# HH_Fixed tensor(0.0093, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 82/1000, Loss: 0.0007, loss_vec: 0.0002, loss_image: 0.0006, Shift Range: ±1 pixels
# LL_Moving tensor(0.1784, device='cuda:0')
# HH_Moving tensor(0.0094, device='cuda:0')
# LL_Fixed tensor(0.1783, device='cuda:0')
# HH_Fixed tensor(0.0089, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 83/1000, Loss: 0.0010, loss_vec: 0.0002, loss_image: 0.0007, Shift Range: ±1 pixels
# LL_Moving tensor(0.2241, device='cuda:0')
# HH_Moving tensor(0.0105, device='cuda:0')
# LL_Fixed tensor(0.2241, device='cuda:0')
# HH_Fixed tensor(0.0099, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 84/1000, Loss: 0.0008, loss_vec: 0.0002, loss_image: 0.0006, Shift Range: ±1 pixels
# LL_Moving tensor(0.1593, device='cuda:0')
# HH_Moving tensor(0.0082, device='cuda:0')
# LL_Fixed tensor(0.1592, device='cuda:0')
# HH_Fixed tensor(0.0077, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 85/1000, Loss: 0.0006, loss_vec: 0.0002, loss_image: 0.0004, Shift Range: ±1 pixels
# LL_Moving tensor(0.1676, device='cuda:0')
# HH_Moving tensor(0.0083, device='cuda:0')
# LL_Fixed tensor(0.1676, device='cuda:0')
# HH_Fixed tensor(0.0079, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 86/1000, Loss: 0.0007, loss_vec: 0.0002, loss_image: 0.0005, Shift Range: ±1 pixels
# LL_Moving tensor(0.2387, device='cuda:0')
# HH_Moving tensor(0.0124, device='cuda:0')
# LL_Fixed tensor(0.2386, device='cuda:0')
# HH_Fixed tensor(0.0117, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 87/1000, Loss: 0.0009, loss_vec: 0.0002, loss_image: 0.0007, Shift Range: ±1 pixels
# LL_Moving tensor(0.2018, device='cuda:0')
# HH_Moving tensor(0.0098, device='cuda:0')
# LL_Fixed tensor(0.2017, device='cuda:0')
# HH_Fixed tensor(0.0094, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 88/1000, Loss: 0.0006, loss_vec: 0.0002, loss_image: 0.0004, Shift Range: ±1 pixels
# LL_Moving tensor(0.2265, device='cuda:0')
# HH_Moving tensor(0.0104, device='cuda:0')
# LL_Fixed tensor(0.2265, device='cuda:0')
# HH_Fixed tensor(0.0097, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 89/1000, Loss: 0.0009, loss_vec: 0.0002, loss_image: 0.0007, Shift Range: ±1 pixels
# LL_Moving tensor(0.1844, device='cuda:0')
# HH_Moving tensor(0.0089, device='cuda:0')
# LL_Fixed tensor(0.1843, device='cuda:0')
# HH_Fixed tensor(0.0085, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 90/1000, Loss: 0.0007, loss_vec: 0.0002, loss_image: 0.0004, Shift Range: ±1 pixels
# LL_Moving tensor(0.2363, device='cuda:0')
# HH_Moving tensor(0.0112, device='cuda:0')
# LL_Fixed tensor(0.2362, device='cuda:0')
# HH_Fixed tensor(0.0105, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 91/1000, Loss: 0.0009, loss_vec: 0.0002, loss_image: 0.0007, Shift Range: ±1 pixels
# LL_Moving tensor(0.2016, device='cuda:0')
# HH_Moving tensor(0.0097, device='cuda:0')
# LL_Fixed tensor(0.2016, device='cuda:0')
# HH_Fixed tensor(0.0092, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 92/1000, Loss: 0.0009, loss_vec: 0.0002, loss_image: 0.0007, Shift Range: ±1 pixels
# LL_Moving tensor(0.2075, device='cuda:0')
# HH_Moving tensor(0.0100, device='cuda:0')
# LL_Fixed tensor(0.2074, device='cuda:0')
# HH_Fixed tensor(0.0094, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 93/1000, Loss: 0.0009, loss_vec: 0.0002, loss_image: 0.0007, Shift Range: ±1 pixels
# LL_Moving tensor(0.1829, device='cuda:0')
# HH_Moving tensor(0.0098, device='cuda:0')
# LL_Fixed tensor(0.1828, device='cuda:0')
# HH_Fixed tensor(0.0091, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 94/1000, Loss: 0.0011, loss_vec: 0.0003, loss_image: 0.0008, Shift Range: ±1 pixels
# LL_Moving tensor(0.1819, device='cuda:0')
# HH_Moving tensor(0.0084, device='cuda:0')
# LL_Fixed tensor(0.1818, device='cuda:0')
# HH_Fixed tensor(0.0080, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 95/1000, Loss: 0.0006, loss_vec: 0.0002, loss_image: 0.0004, Shift Range: ±1 pixels
# LL_Moving tensor(0.2668, device='cuda:0')
# HH_Moving tensor(0.0136, device='cuda:0')
# LL_Fixed tensor(0.2667, device='cuda:0')
# HH_Fixed tensor(0.0128, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 96/1000, Loss: 0.0011, loss_vec: 0.0002, loss_image: 0.0009, Shift Range: ±1 pixels
# LL_Moving tensor(0.2212, device='cuda:0')
# HH_Moving tensor(0.0112, device='cuda:0')
# LL_Fixed tensor(0.2212, device='cuda:0')
# HH_Fixed tensor(0.0106, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 97/1000, Loss: 0.0008, loss_vec: 0.0002, loss_image: 0.0006, Shift Range: ±1 pixels
# LL_Moving tensor(0.1676, device='cuda:0')
# HH_Moving tensor(0.0095, device='cuda:0')
# LL_Fixed tensor(0.1675, device='cuda:0')
# HH_Fixed tensor(0.0089, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 98/1000, Loss: 0.0009, loss_vec: 0.0002, loss_image: 0.0007, Shift Range: ±1 pixels
# LL_Moving tensor(0.1664, device='cuda:0')
# HH_Moving tensor(0.0086, device='cuda:0')
# LL_Fixed tensor(0.1663, device='cuda:0')
# HH_Fixed tensor(0.0082, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 99/1000, Loss: 0.0007, loss_vec: 0.0002, loss_image: 0.0005, Shift Range: ±1 pixels
# LL_Moving tensor(0.2008, device='cuda:0')
# HH_Moving tensor(0.0100, device='cuda:0')
# LL_Fixed tensor(0.2007, device='cuda:0')
# HH_Fixed tensor(0.0095, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 100/1000, Loss: 0.0007, loss_vec: 0.0002, loss_image: 0.0005, Shift Range: ±1 pixels
# Epoch 100: Increasing shift range to ±6 pixels.
# LL_Moving tensor(0.2441, device='cuda:0')
# HH_Moving tensor(0.0107, device='cuda:0')
# LL_Fixed tensor(0.2435, device='cuda:0')
# HH_Fixed tensor(0.0082, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 101/1000, Loss: 0.0247, loss_vec: 0.0057, loss_image: 0.0190, Shift Range: ±6 pixels
# LL_Moving tensor(0.2430, device='cuda:0')
# HH_Moving tensor(0.0123, device='cuda:0')
# LL_Fixed tensor(0.2423, device='cuda:0')
# HH_Fixed tensor(0.0095, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 102/1000, Loss: 0.0407, loss_vec: 0.0067, loss_image: 0.0340, Shift Range: ±6 pixels
# LL_Moving tensor(0.2381, device='cuda:0')
# HH_Moving tensor(0.0126, device='cuda:0')
# LL_Fixed tensor(0.2378, device='cuda:0')
# HH_Fixed tensor(0.0096, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 103/1000, Loss: 0.0330, loss_vec: 0.0067, loss_image: 0.0264, Shift Range: ±6 pixels
# LL_Moving tensor(0.1692, device='cuda:0')
# HH_Moving tensor(0.0085, device='cuda:0')
# LL_Fixed tensor(0.1692, device='cuda:0')
# HH_Fixed tensor(0.0065, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 104/1000, Loss: 0.0286, loss_vec: 0.0068, loss_image: 0.0218, Shift Range: ±6 pixels
# LL_Moving tensor(0.1396, device='cuda:0')
# HH_Moving tensor(0.0061, device='cuda:0')
# LL_Fixed tensor(0.1392, device='cuda:0')
# HH_Fixed tensor(0.0048, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 105/1000, Loss: 0.0139, loss_vec: 0.0065, loss_image: 0.0075, Shift Range: ±6 pixels
# LL_Moving tensor(0.2199, device='cuda:0')
# HH_Moving tensor(0.0105, device='cuda:0')
# LL_Fixed tensor(0.2192, device='cuda:0')
# HH_Fixed tensor(0.0077, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 106/1000, Loss: 0.0185, loss_vec: 0.0060, loss_image: 0.0125, Shift Range: ±6 pixels
# LL_Moving tensor(0.2147, device='cuda:0')
# HH_Moving tensor(0.0104, device='cuda:0')
# LL_Fixed tensor(0.2142, device='cuda:0')
# HH_Fixed tensor(0.0081, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 107/1000, Loss: 0.0327, loss_vec: 0.0072, loss_image: 0.0255, Shift Range: ±6 pixels
# LL_Moving tensor(0.2376, device='cuda:0')
# HH_Moving tensor(0.0115, device='cuda:0')
# LL_Fixed tensor(0.2366, device='cuda:0')
# HH_Fixed tensor(0.0085, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 108/1000, Loss: 0.0330, loss_vec: 0.0087, loss_image: 0.0243, Shift Range: ±6 pixels
# LL_Moving tensor(0.2233, device='cuda:0')
# HH_Moving tensor(0.0093, device='cuda:0')
# LL_Fixed tensor(0.2227, device='cuda:0')
# HH_Fixed tensor(0.0070, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 109/1000, Loss: 0.0251, loss_vec: 0.0080, loss_image: 0.0171, Shift Range: ±6 pixels
# LL_Moving tensor(0.2071, device='cuda:0')
# HH_Moving tensor(0.0097, device='cuda:0')
# LL_Fixed tensor(0.2067, device='cuda:0')
# HH_Fixed tensor(0.0073, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 110/1000, Loss: 0.0216, loss_vec: 0.0069, loss_image: 0.0147, Shift Range: ±6 pixels
# LL_Moving tensor(0.1960, device='cuda:0')
# HH_Moving tensor(0.0109, device='cuda:0')
# LL_Fixed tensor(0.1955, device='cuda:0')
# HH_Fixed tensor(0.0085, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 111/1000, Loss: 0.0279, loss_vec: 0.0067, loss_image: 0.0213, Shift Range: ±6 pixels
# LL_Moving tensor(0.1544, device='cuda:0')
# HH_Moving tensor(0.0083, device='cuda:0')
# LL_Fixed tensor(0.1543, device='cuda:0')
# HH_Fixed tensor(0.0065, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 112/1000, Loss: 0.0204, loss_vec: 0.0055, loss_image: 0.0149, Shift Range: ±6 pixels
# LL_Moving tensor(0.2191, device='cuda:0')
# HH_Moving tensor(0.0104, device='cuda:0')
# LL_Fixed tensor(0.2183, device='cuda:0')
# HH_Fixed tensor(0.0077, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 113/1000, Loss: 0.0305, loss_vec: 0.0073, loss_image: 0.0233, Shift Range: ±6 pixels
# LL_Moving tensor(0.1987, device='cuda:0')
# HH_Moving tensor(0.0101, device='cuda:0')
# LL_Fixed tensor(0.1981, device='cuda:0')
# HH_Fixed tensor(0.0077, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 114/1000, Loss: 0.0301, loss_vec: 0.0065, loss_image: 0.0236, Shift Range: ±6 pixels
# LL_Moving tensor(0.2008, device='cuda:0')
# HH_Moving tensor(0.0108, device='cuda:0')
# LL_Fixed tensor(0.2003, device='cuda:0')
# HH_Fixed tensor(0.0084, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 115/1000, Loss: 0.0322, loss_vec: 0.0076, loss_image: 0.0246, Shift Range: ±6 pixels
# LL_Moving tensor(0.2080, device='cuda:0')
# HH_Moving tensor(0.0099, device='cuda:0')
# LL_Fixed tensor(0.2074, device='cuda:0')
# HH_Fixed tensor(0.0073, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 116/1000, Loss: 0.0327, loss_vec: 0.0083, loss_image: 0.0244, Shift Range: ±6 pixels
# LL_Moving tensor(0.1762, device='cuda:0')
# HH_Moving tensor(0.0088, device='cuda:0')
# LL_Fixed tensor(0.1758, device='cuda:0')
# HH_Fixed tensor(0.0066, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 117/1000, Loss: 0.0234, loss_vec: 0.0071, loss_image: 0.0163, Shift Range: ±6 pixels
# LL_Moving tensor(0.1677, device='cuda:0')
# HH_Moving tensor(0.0083, device='cuda:0')
# LL_Fixed tensor(0.1675, device='cuda:0')
# HH_Fixed tensor(0.0065, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 118/1000, Loss: 0.0242, loss_vec: 0.0075, loss_image: 0.0167, Shift Range: ±6 pixels
# LL_Moving tensor(0.2113, device='cuda:0')
# HH_Moving tensor(0.0111, device='cuda:0')
# LL_Fixed tensor(0.2110, device='cuda:0')
# HH_Fixed tensor(0.0085, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 119/1000, Loss: 0.0252, loss_vec: 0.0070, loss_image: 0.0182, Shift Range: ±6 pixels
# LL_Moving tensor(0.1677, device='cuda:0')
# HH_Moving tensor(0.0084, device='cuda:0')
# LL_Fixed tensor(0.1675, device='cuda:0')
# HH_Fixed tensor(0.0065, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 120/1000, Loss: 0.0244, loss_vec: 0.0075, loss_image: 0.0168, Shift Range: ±6 pixels
# LL_Moving tensor(0.1750, device='cuda:0')
# HH_Moving tensor(0.0085, device='cuda:0')
# LL_Fixed tensor(0.1746, device='cuda:0')
# HH_Fixed tensor(0.0067, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 121/1000, Loss: 0.0294, loss_vec: 0.0067, loss_image: 0.0227, Shift Range: ±6 pixels
# LL_Moving tensor(0.1766, device='cuda:0')
# HH_Moving tensor(0.0089, device='cuda:0')
# LL_Fixed tensor(0.1759, device='cuda:0')
# HH_Fixed tensor(0.0068, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 122/1000, Loss: 0.0250, loss_vec: 0.0078, loss_image: 0.0172, Shift Range: ±6 pixels
# LL_Moving tensor(0.1902, device='cuda:0')
# HH_Moving tensor(0.0100, device='cuda:0')
# LL_Fixed tensor(0.1901, device='cuda:0')
# HH_Fixed tensor(0.0078, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 123/1000, Loss: 0.0293, loss_vec: 0.0066, loss_image: 0.0227, Shift Range: ±6 pixels
# LL_Moving tensor(0.1812, device='cuda:0')
# HH_Moving tensor(0.0084, device='cuda:0')
# LL_Fixed tensor(0.1804, device='cuda:0')
# HH_Fixed tensor(0.0063, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 124/1000, Loss: 0.0271, loss_vec: 0.0087, loss_image: 0.0184, Shift Range: ±6 pixels
# LL_Moving tensor(0.2005, device='cuda:0')
# HH_Moving tensor(0.0098, device='cuda:0')
# LL_Fixed tensor(0.2003, device='cuda:0')
# HH_Fixed tensor(0.0075, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 125/1000, Loss: 0.0238, loss_vec: 0.0067, loss_image: 0.0170, Shift Range: ±6 pixels
# LL_Moving tensor(0.1777, device='cuda:0')
# HH_Moving tensor(0.0095, device='cuda:0')
# LL_Fixed tensor(0.1776, device='cuda:0')
# HH_Fixed tensor(0.0073, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 126/1000, Loss: 0.0287, loss_vec: 0.0084, loss_image: 0.0203, Shift Range: ±6 pixels
# LL_Moving tensor(0.2235, device='cuda:0')
# HH_Moving tensor(0.0102, device='cuda:0')
# LL_Fixed tensor(0.2229, device='cuda:0')
# HH_Fixed tensor(0.0078, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 127/1000, Loss: 0.0243, loss_vec: 0.0072, loss_image: 0.0171, Shift Range: ±6 pixels
# LL_Moving tensor(0.1852, device='cuda:0')
# HH_Moving tensor(0.0093, device='cuda:0')
# LL_Fixed tensor(0.1850, device='cuda:0')
# HH_Fixed tensor(0.0071, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 128/1000, Loss: 0.0322, loss_vec: 0.0084, loss_image: 0.0238, Shift Range: ±6 pixels
# LL_Moving tensor(0.1940, device='cuda:0')
# HH_Moving tensor(0.0097, device='cuda:0')
# LL_Fixed tensor(0.1934, device='cuda:0')
# HH_Fixed tensor(0.0074, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 129/1000, Loss: 0.0268, loss_vec: 0.0075, loss_image: 0.0193, Shift Range: ±6 pixels
# LL_Moving tensor(0.2333, device='cuda:0')
# HH_Moving tensor(0.0101, device='cuda:0')
# LL_Fixed tensor(0.2328, device='cuda:0')
# HH_Fixed tensor(0.0074, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 130/1000, Loss: 0.0321, loss_vec: 0.0086, loss_image: 0.0235, Shift Range: ±6 pixels
# LL_Moving tensor(0.1884, device='cuda:0')
# HH_Moving tensor(0.0100, device='cuda:0')
# LL_Fixed tensor(0.1882, device='cuda:0')
# HH_Fixed tensor(0.0077, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 131/1000, Loss: 0.0326, loss_vec: 0.0086, loss_image: 0.0240, Shift Range: ±6 pixels
# LL_Moving tensor(0.2357, device='cuda:0')
# HH_Moving tensor(0.0125, device='cuda:0')
# LL_Fixed tensor(0.2350, device='cuda:0')
# HH_Fixed tensor(0.0094, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 132/1000, Loss: 0.0273, loss_vec: 0.0068, loss_image: 0.0205, Shift Range: ±6 pixels
# LL_Moving tensor(0.1797, device='cuda:0')
# HH_Moving tensor(0.0101, device='cuda:0')
# LL_Fixed tensor(0.1792, device='cuda:0')
# HH_Fixed tensor(0.0079, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 133/1000, Loss: 0.0316, loss_vec: 0.0071, loss_image: 0.0245, Shift Range: ±6 pixels
# LL_Moving tensor(0.2217, device='cuda:0')
# HH_Moving tensor(0.0100, device='cuda:0')
# LL_Fixed tensor(0.2211, device='cuda:0')
# HH_Fixed tensor(0.0075, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 134/1000, Loss: 0.0275, loss_vec: 0.0072, loss_image: 0.0203, Shift Range: ±6 pixels
# LL_Moving tensor(0.2719, device='cuda:0')
# HH_Moving tensor(0.0128, device='cuda:0')
# LL_Fixed tensor(0.2717, device='cuda:0')
# HH_Fixed tensor(0.0095, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 135/1000, Loss: 0.0279, loss_vec: 0.0067, loss_image: 0.0212, Shift Range: ±6 pixels
# LL_Moving tensor(0.2286, device='cuda:0')
# HH_Moving tensor(0.0108, device='cuda:0')
# LL_Fixed tensor(0.2277, device='cuda:0')
# HH_Fixed tensor(0.0080, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 136/1000, Loss: 0.0272, loss_vec: 0.0070, loss_image: 0.0202, Shift Range: ±6 pixels
# LL_Moving tensor(0.2154, device='cuda:0')
# HH_Moving tensor(0.0108, device='cuda:0')
# LL_Fixed tensor(0.2151, device='cuda:0')
# HH_Fixed tensor(0.0083, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 137/1000, Loss: 0.0332, loss_vec: 0.0071, loss_image: 0.0261, Shift Range: ±6 pixels
# LL_Moving tensor(0.2180, device='cuda:0')
# HH_Moving tensor(0.0104, device='cuda:0')
# LL_Fixed tensor(0.2174, device='cuda:0')
# HH_Fixed tensor(0.0078, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 138/1000, Loss: 0.0244, loss_vec: 0.0068, loss_image: 0.0176, Shift Range: ±6 pixels
# LL_Moving tensor(0.2154, device='cuda:0')
# HH_Moving tensor(0.0106, device='cuda:0')
# LL_Fixed tensor(0.2151, device='cuda:0')
# HH_Fixed tensor(0.0083, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 139/1000, Loss: 0.0378, loss_vec: 0.0093, loss_image: 0.0285, Shift Range: ±6 pixels
# LL_Moving tensor(0.1902, device='cuda:0')
# HH_Moving tensor(0.0095, device='cuda:0')
# LL_Fixed tensor(0.1897, device='cuda:0')
# HH_Fixed tensor(0.0074, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 140/1000, Loss: 0.0212, loss_vec: 0.0070, loss_image: 0.0142, Shift Range: ±6 pixels
# LL_Moving tensor(0.2189, device='cuda:0')
# HH_Moving tensor(0.0093, device='cuda:0')
# LL_Fixed tensor(0.2186, device='cuda:0')
# HH_Fixed tensor(0.0070, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 141/1000, Loss: 0.0233, loss_vec: 0.0066, loss_image: 0.0168, Shift Range: ±6 pixels
# LL_Moving tensor(0.2098, device='cuda:0')
# HH_Moving tensor(0.0110, device='cuda:0')
# LL_Fixed tensor(0.2092, device='cuda:0')
# HH_Fixed tensor(0.0086, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 142/1000, Loss: 0.0223, loss_vec: 0.0063, loss_image: 0.0160, Shift Range: ±6 pixels
# LL_Moving tensor(0.1919, device='cuda:0')
# HH_Moving tensor(0.0083, device='cuda:0')
# LL_Fixed tensor(0.1917, device='cuda:0')
# HH_Fixed tensor(0.0065, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 143/1000, Loss: 0.0156, loss_vec: 0.0056, loss_image: 0.0100, Shift Range: ±6 pixels
# LL_Moving tensor(0.1819, device='cuda:0')
# HH_Moving tensor(0.0090, device='cuda:0')
# LL_Fixed tensor(0.1813, device='cuda:0')
# HH_Fixed tensor(0.0069, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 144/1000, Loss: 0.0276, loss_vec: 0.0067, loss_image: 0.0209, Shift Range: ±6 pixels
# LL_Moving tensor(0.1297, device='cuda:0')
# HH_Moving tensor(0.0081, device='cuda:0')
# LL_Fixed tensor(0.1294, device='cuda:0')
# HH_Fixed tensor(0.0062, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 145/1000, Loss: 0.0233, loss_vec: 0.0079, loss_image: 0.0154, Shift Range: ±6 pixels
# LL_Moving tensor(0.2625, device='cuda:0')
# HH_Moving tensor(0.0134, device='cuda:0')
# LL_Fixed tensor(0.2619, device='cuda:0')
# HH_Fixed tensor(0.0101, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 146/1000, Loss: 0.0289, loss_vec: 0.0073, loss_image: 0.0216, Shift Range: ±6 pixels
# LL_Moving tensor(0.2070, device='cuda:0')
# HH_Moving tensor(0.0096, device='cuda:0')
# LL_Fixed tensor(0.2066, device='cuda:0')
# HH_Fixed tensor(0.0075, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# ...
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 426/1000, Loss: 0.1274, loss_vec: 0.0716, loss_image: 0.0558, Shift Range: ±21 pixels
# LL_Moving tensor(0.1447, device='cuda:0')
# HH_Moving tensor(0.0083, device='cuda:0')
# LL_Fixed tensor(0.1447, device='cuda:0')
# HH_Fixed tensor(0.0060, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 427/1000, Loss: 0.1311, loss_vec: 0.0830, loss_image: 0.0481, Shift Range: ±21 pixels
# LL_Moving tensor(0.1563, device='cuda:0')
# HH_Moving tensor(0.0074, device='cuda:0')
# LL_Fixed tensor(0.1545, device='cuda:0')
# HH_Fixed tensor(0.0052, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 428/1000, Loss: 0.1109, loss_vec: 0.0741, loss_image: 0.0367, Shift Range: ±21 pixels
# LL_Moving tensor(0.2042, device='cuda:0')
# HH_Moving tensor(0.0104, device='cuda:0')
# LL_Fixed tensor(0.2014, device='cuda:0')
# HH_Fixed tensor(0.0074, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 429/1000, Loss: 0.1447, loss_vec: 0.0763, loss_image: 0.0683, Shift Range: ±21 pixels
# LL_Moving tensor(0.1654, device='cuda:0')
# HH_Moving tensor(0.0082, device='cuda:0')
# LL_Fixed tensor(0.1641, device='cuda:0')
# HH_Fixed tensor(0.0058, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 430/1000, Loss: 0.1031, loss_vec: 0.0637, loss_image: 0.0395, Shift Range: ±21 pixels
# LL_Moving tensor(0.1322, device='cuda:0')
# HH_Moving tensor(0.0058, device='cuda:0')
# LL_Fixed tensor(0.1303, device='cuda:0')
# HH_Fixed tensor(0.0041, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 431/1000, Loss: 0.1031, loss_vec: 0.0802, loss_image: 0.0229, Shift Range: ±21 pixels
# LL_Moving tensor(0.1890, device='cuda:0')
# HH_Moving tensor(0.0109, device='cuda:0')
# LL_Fixed tensor(0.1868, device='cuda:0')
# HH_Fixed tensor(0.0077, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 432/1000, Loss: 0.1414, loss_vec: 0.0650, loss_image: 0.0764, Shift Range: ±21 pixels
# LL_Moving tensor(0.1792, device='cuda:0')
# HH_Moving tensor(0.0094, device='cuda:0')
# LL_Fixed tensor(0.1778, device='cuda:0')
# HH_Fixed tensor(0.0067, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 433/1000, Loss: 0.1473, loss_vec: 0.0771, loss_image: 0.0703, Shift Range: ±21 pixels
# LL_Moving tensor(0.1653, device='cuda:0')
# HH_Moving tensor(0.0084, device='cuda:0')
# LL_Fixed tensor(0.1643, device='cuda:0')
# HH_Fixed tensor(0.0060, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 434/1000, Loss: 0.1284, loss_vec: 0.0734, loss_image: 0.0550, Shift Range: ±21 pixels
# LL_Moving tensor(0.1814, device='cuda:0')
# HH_Moving tensor(0.0076, device='cuda:0')
# LL_Fixed tensor(0.1794, device='cuda:0')
# HH_Fixed tensor(0.0054, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 435/1000, Loss: 0.1341, loss_vec: 0.0788, loss_image: 0.0554, Shift Range: ±21 pixels
# LL_Moving tensor(0.1743, device='cuda:0')
# HH_Moving tensor(0.0089, device='cuda:0')
# LL_Fixed tensor(0.1737, device='cuda:0')
# HH_Fixed tensor(0.0063, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 436/1000, Loss: 0.1236, loss_vec: 0.0743, loss_image: 0.0494, Shift Range: ±21 pixels
# LL_Moving tensor(0.1902, device='cuda:0')
# HH_Moving tensor(0.0091, device='cuda:0')
# LL_Fixed tensor(0.1880, device='cuda:0')
# HH_Fixed tensor(0.0065, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 437/1000, Loss: 0.1304, loss_vec: 0.0697, loss_image: 0.0607, Shift Range: ±21 pixels
# LL_Moving tensor(0.2198, device='cuda:0')
# HH_Moving tensor(0.0104, device='cuda:0')
# LL_Fixed tensor(0.2174, device='cuda:0')
# HH_Fixed tensor(0.0074, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 438/1000, Loss: 0.1763, loss_vec: 0.0871, loss_image: 0.0892, Shift Range: ±21 pixels
# LL_Moving tensor(0.1654, device='cuda:0')
# HH_Moving tensor(0.0075, device='cuda:0')
# LL_Fixed tensor(0.1635, device='cuda:0')
# HH_Fixed tensor(0.0053, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 439/1000, Loss: 0.1198, loss_vec: 0.0795, loss_image: 0.0403, Shift Range: ±21 pixels
# LL_Moving tensor(0.2014, device='cuda:0')
# HH_Moving tensor(0.0100, device='cuda:0')
# LL_Fixed tensor(0.1998, device='cuda:0')
# HH_Fixed tensor(0.0072, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 440/1000, Loss: 0.1394, loss_vec: 0.0751, loss_image: 0.0643, Shift Range: ±21 pixels
# LL_Moving tensor(0.1652, device='cuda:0')
# HH_Moving tensor(0.0077, device='cuda:0')
# LL_Fixed tensor(0.1648, device='cuda:0')
# HH_Fixed tensor(0.0056, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 441/1000, Loss: 0.1392, loss_vec: 0.0840, loss_image: 0.0552, Shift Range: ±21 pixels
# LL_Moving tensor(0.1792, device='cuda:0')
# HH_Moving tensor(0.0089, device='cuda:0')
# LL_Fixed tensor(0.1767, device='cuda:0')
# HH_Fixed tensor(0.0064, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 442/1000, Loss: 0.1476, loss_vec: 0.0745, loss_image: 0.0731, Shift Range: ±21 pixels
# LL_Moving tensor(0.2369, device='cuda:0')
# HH_Moving tensor(0.0104, device='cuda:0')
# LL_Fixed tensor(0.2352, device='cuda:0')
# HH_Fixed tensor(0.0072, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 443/1000, Loss: 0.1373, loss_vec: 0.0730, loss_image: 0.0643, Shift Range: ±21 pixels
# LL_Moving tensor(0.2208, device='cuda:0')
# HH_Moving tensor(0.0109, device='cuda:0')
# LL_Fixed tensor(0.2201, device='cuda:0')
# HH_Fixed tensor(0.0075, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 444/1000, Loss: 0.1367, loss_vec: 0.0770, loss_image: 0.0598, Shift Range: ±21 pixels
# LL_Moving tensor(0.1726, device='cuda:0')
# HH_Moving tensor(0.0086, device='cuda:0')
# LL_Fixed tensor(0.1720, device='cuda:0')
# HH_Fixed tensor(0.0063, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 445/1000, Loss: 0.1661, loss_vec: 0.0952, loss_image: 0.0709, Shift Range: ±21 pixels
# LL_Moving tensor(0.2240, device='cuda:0')
# HH_Moving tensor(0.0125, device='cuda:0')
# LL_Fixed tensor(0.2221, device='cuda:0')
# HH_Fixed tensor(0.0087, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 446/1000, Loss: 0.1545, loss_vec: 0.0732, loss_image: 0.0813, Shift Range: ±21 pixels
# LL_Moving tensor(0.2095, device='cuda:0')
# HH_Moving tensor(0.0116, device='cuda:0')
# LL_Fixed tensor(0.2075, device='cuda:0')
# HH_Fixed tensor(0.0083, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 447/1000, Loss: 0.1746, loss_vec: 0.0785, loss_image: 0.0961, Shift Range: ±21 pixels
# LL_Moving tensor(0.1922, device='cuda:0')
# HH_Moving tensor(0.0095, device='cuda:0')
# LL_Fixed tensor(0.1909, device='cuda:0')
# HH_Fixed tensor(0.0070, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 448/1000, Loss: 0.1388, loss_vec: 0.0707, loss_image: 0.0681, Shift Range: ±21 pixels
# LL_Moving tensor(0.2698, device='cuda:0')
# HH_Moving tensor(0.0121, device='cuda:0')
# LL_Fixed tensor(0.2683, device='cuda:0')
# HH_Fixed tensor(0.0082, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 449/1000, Loss: 0.1445, loss_vec: 0.0721, loss_image: 0.0724, Shift Range: ±21 pixels
# LL_Moving tensor(0.1580, device='cuda:0')
# HH_Moving tensor(0.0094, device='cuda:0')
# LL_Fixed tensor(0.1561, device='cuda:0')
# HH_Fixed tensor(0.0067, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 450/1000, Loss: 0.1311, loss_vec: 0.0808, loss_image: 0.0504, Shift Range: ±21 pixels
# LL_Moving tensor(0.1703, device='cuda:0')
# HH_Moving tensor(0.0076, device='cuda:0')
# LL_Fixed tensor(0.1690, device='cuda:0')
# HH_Fixed tensor(0.0053, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 451/1000, Loss: 0.1119, loss_vec: 0.0742, loss_image: 0.0378, Shift Range: ±21 pixels
# LL_Moving tensor(0.1747, device='cuda:0')
# HH_Moving tensor(0.0086, device='cuda:0')
# LL_Fixed tensor(0.1726, device='cuda:0')
# HH_Fixed tensor(0.0062, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 452/1000, Loss: 0.1399, loss_vec: 0.0819, loss_image: 0.0580, Shift Range: ±21 pixels
# LL_Moving tensor(0.2074, device='cuda:0')
# HH_Moving tensor(0.0110, device='cuda:0')
# LL_Fixed tensor(0.2061, device='cuda:0')
# HH_Fixed tensor(0.0080, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 453/1000, Loss: 0.1674, loss_vec: 0.0887, loss_image: 0.0787, Shift Range: ±21 pixels
# LL_Moving tensor(0.2064, device='cuda:0')
# HH_Moving tensor(0.0109, device='cuda:0')
# LL_Fixed tensor(0.2051, device='cuda:0')
# HH_Fixed tensor(0.0078, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 454/1000, Loss: 0.1139, loss_vec: 0.0625, loss_image: 0.0514, Shift Range: ±21 pixels
# LL_Moving tensor(0.2075, device='cuda:0')
# HH_Moving tensor(0.0093, device='cuda:0')
# LL_Fixed tensor(0.2060, device='cuda:0')
# HH_Fixed tensor(0.0065, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 455/1000, Loss: 0.1493, loss_vec: 0.0818, loss_image: 0.0674, Shift Range: ±21 pixels
# LL_Moving tensor(0.2280, device='cuda:0')
# HH_Moving tensor(0.0120, device='cuda:0')
# LL_Fixed tensor(0.2253, device='cuda:0')
# HH_Fixed tensor(0.0087, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 456/1000, Loss: 0.1733, loss_vec: 0.0759, loss_image: 0.0974, Shift Range: ±21 pixels
# LL_Moving tensor(0.2386, device='cuda:0')
# HH_Moving tensor(0.0110, device='cuda:0')
# LL_Fixed tensor(0.2355, device='cuda:0')
# HH_Fixed tensor(0.0079, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 457/1000, Loss: 0.1396, loss_vec: 0.0717, loss_image: 0.0679, Shift Range: ±21 pixels
# LL_Moving tensor(0.2071, device='cuda:0')
# HH_Moving tensor(0.0102, device='cuda:0')
# LL_Fixed tensor(0.2052, device='cuda:0')
# HH_Fixed tensor(0.0073, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 458/1000, Loss: 0.1046, loss_vec: 0.0632, loss_image: 0.0414, Shift Range: ±21 pixels
# LL_Moving tensor(0.2061, device='cuda:0')
# HH_Moving tensor(0.0112, device='cuda:0')
# LL_Fixed tensor(0.2048, device='cuda:0')
# HH_Fixed tensor(0.0077, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 459/1000, Loss: 0.1609, loss_vec: 0.0783, loss_image: 0.0826, Shift Range: ±21 pixels
# LL_Moving tensor(0.2202, device='cuda:0')
# HH_Moving tensor(0.0108, device='cuda:0')
# LL_Fixed tensor(0.2184, device='cuda:0')
# HH_Fixed tensor(0.0078, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 460/1000, Loss: 0.1559, loss_vec: 0.0777, loss_image: 0.0782, Shift Range: ±21 pixels
# LL_Moving tensor(0.1711, device='cuda:0')
# HH_Moving tensor(0.0089, device='cuda:0')
# LL_Fixed tensor(0.1701, device='cuda:0')
# HH_Fixed tensor(0.0065, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 461/1000, Loss: 0.1354, loss_vec: 0.0806, loss_image: 0.0549, Shift Range: ±21 pixels
# LL_Moving tensor(0.1923, device='cuda:0')
# HH_Moving tensor(0.0095, device='cuda:0')
# LL_Fixed tensor(0.1919, device='cuda:0')
# HH_Fixed tensor(0.0067, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 462/1000, Loss: 0.1228, loss_vec: 0.0769, loss_image: 0.0459, Shift Range: ±21 pixels
# LL_Moving tensor(0.2126, device='cuda:0')
# HH_Moving tensor(0.0102, device='cuda:0')
# LL_Fixed tensor(0.2107, device='cuda:0')
# HH_Fixed tensor(0.0071, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 463/1000, Loss: 0.1421, loss_vec: 0.0784, loss_image: 0.0637, Shift Range: ±21 pixels
# LL_Moving tensor(0.1828, device='cuda:0')
# HH_Moving tensor(0.0087, device='cuda:0')
# LL_Fixed tensor(0.1814, device='cuda:0')
# HH_Fixed tensor(0.0062, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 464/1000, Loss: 0.1201, loss_vec: 0.0695, loss_image: 0.0505, Shift Range: ±21 pixels
# LL_Moving tensor(0.1723, device='cuda:0')
# HH_Moving tensor(0.0082, device='cuda:0')
# LL_Fixed tensor(0.1714, device='cuda:0')
# HH_Fixed tensor(0.0058, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 465/1000, Loss: 0.1267, loss_vec: 0.0755, loss_image: 0.0512, Shift Range: ±21 pixels
# LL_Moving tensor(0.2376, device='cuda:0')
# HH_Moving tensor(0.0115, device='cuda:0')
# LL_Fixed tensor(0.2349, device='cuda:0')
# HH_Fixed tensor(0.0080, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 466/1000, Loss: 0.1501, loss_vec: 0.0754, loss_image: 0.0747, Shift Range: ±21 pixels
# LL_Moving tensor(0.1964, device='cuda:0')
# HH_Moving tensor(0.0098, device='cuda:0')
# LL_Fixed tensor(0.1955, device='cuda:0')
# HH_Fixed tensor(0.0069, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 467/1000, Loss: 0.1162, loss_vec: 0.0689, loss_image: 0.0473, Shift Range: ±21 pixels
# LL_Moving tensor(0.1865, device='cuda:0')
# HH_Moving tensor(0.0085, device='cuda:0')
# LL_Fixed tensor(0.1857, device='cuda:0')
# HH_Fixed tensor(0.0060, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 468/1000, Loss: 0.1202, loss_vec: 0.0802, loss_image: 0.0401, Shift Range: ±21 pixels
# LL_Moving tensor(0.2246, device='cuda:0')
# HH_Moving tensor(0.0122, device='cuda:0')
# LL_Fixed tensor(0.2227, device='cuda:0')
# HH_Fixed tensor(0.0085, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 469/1000, Loss: 0.1182, loss_vec: 0.0626, loss_image: 0.0556, Shift Range: ±21 pixels
# LL_Moving tensor(0.2188, device='cuda:0')
# HH_Moving tensor(0.0124, device='cuda:0')
# LL_Fixed tensor(0.2171, device='cuda:0')
# HH_Fixed tensor(0.0087, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 470/1000, Loss: 0.1520, loss_vec: 0.0787, loss_image: 0.0733, Shift Range: ±21 pixels
# LL_Moving tensor(0.2328, device='cuda:0')
# HH_Moving tensor(0.0113, device='cuda:0')
# LL_Fixed tensor(0.2307, device='cuda:0')
# HH_Fixed tensor(0.0079, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 471/1000, Loss: 0.1850, loss_vec: 0.0812, loss_image: 0.1037, Shift Range: ±21 pixels
# LL_Moving tensor(0.2280, device='cuda:0')
# HH_Moving tensor(0.0120, device='cuda:0')
# LL_Fixed tensor(0.2256, device='cuda:0')
# HH_Fixed tensor(0.0086, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 472/1000, Loss: 0.1446, loss_vec: 0.0723, loss_image: 0.0723, Shift Range: ±21 pixels
# LL_Moving tensor(0.2081, device='cuda:0')
# HH_Moving tensor(0.0106, device='cuda:0')
# LL_Fixed tensor(0.2066, device='cuda:0')
# HH_Fixed tensor(0.0078, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 473/1000, Loss: 0.1289, loss_vec: 0.0772, loss_image: 0.0517, Shift Range: ±21 pixels
# LL_Moving tensor(0.1760, device='cuda:0')
# HH_Moving tensor(0.0091, device='cuda:0')
# LL_Fixed tensor(0.1756, device='cuda:0')
# HH_Fixed tensor(0.0066, device='cuda:0')
# torch.Size([2, 3, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# Epoch 474/1000, Loss: 0.1168, loss_vec: 0.0667, loss_image: 0.0501, Shift Range: ±21 pixels
# LL_Moving tensor(0.1844, device='cuda:0')
# HH_Moving tensor(0.0089, device='cuda:0')
# LL_Fixed tensor(0.1847, device='cuda:0')
# HH_Fixed tensor(0.0063, device='cuda:0')

# %%
# # NotdecoderHight
# from tqdm.notebook import tqdm
# transformer = vxm.layers.SpatialTransformer((64, 128, 128)).to(device)

# # 3D ガウシアンフィルタを適用する関数
# def gaussian_smooth_3d(tensor, kernel_size=5, sigma=1.0):
#     """ 3D ガウシアンフィルタで displacement field をスムージング """
#     # 3D Gaussian Kernel の作成
#     from scipy.ndimage import gaussian_filter
#     tensor_np = tensor.cpu().numpy()
#     smoothed_np = gaussian_filter(tensor_np, sigma=[0, 0, sigma, sigma, sigma])  # チャネル方向にはフィルタ適用しない
#     return torch.tensor(smoothed_np, dtype=torch.float32, device=tensor.device)


# # エポック数と最小ロスの設定
# epochs = 50000
# best_loss = float('inf')
# shift_range = 1

# # ロスや他のメトリクスを記録するリスト
# losses = []
# loss_vecs = []
# loss_images = []
# loss_hightVecs = []
# for epoch in tqdm(range(epochs)):
#     # 100エポックごとにshift_rangeを増やす
#     if epoch % 1000 == 0 and epoch > 0:
#         shift_range += 1
#         print(f"Epoch {epoch}: Increasing shift range to ±{shift_range} pixels.")

#     # 学習データのバッチを取得
#     train_batch, _ = next(train_generator)
#     moving_images = torch.tensor(train_batch[0], dtype=torch.float32).to(device)

#     # 画像サイズを設定
#     B, D, H, W = 2, 8, 16, 16  # バッチサイズと画像の次元

#     # displacement_field をボクセルごとにランダムに作成
#     displacement_field = (torch.rand((B, 3, D, H, W), dtype=torch.float32) * 2 - 1) * shift_range
#     displacement_field = displacement_field.to(device)

#     # 3D Gaussian Smoothing を適用
#     displacement_field = gaussian_smooth_3d(displacement_field, sigma=2.0)
#     displacement_field = torch.nn.functional.interpolate(displacement_field, size=(64,128,128), mode='trilinear', align_corners=False)

#     # 位置をずらした画像を生成
#     moving_images2 = transformer(moving_images, displacement_field)

#     # 勾配を初期化
#     optimizer.zero_grad()

#     # 順伝播
#     transformed_image, Vec = model3D_3(moving_images, moving_images2)

#     # 損失を計算
#     loss_vec = MSE_Loss(displacement_field, Vec) * 0.1
#     loss_image = MSE_Loss(moving_images2, transformed_image) * 100
    
#     loss = loss_vec + loss_image

#     # 逆伝播
#     loss.backward()
#     optimizer.step()

#     # モデルを保存
#     torch.save(model3D_3.state_dict(), 'model_VXM_3D_duwl_omomi_karikyuramu.pth')

#     # エポックごとのロスを保存
#     losses.append(loss.cpu().item())
#     loss_vecs.append(loss_vec.cpu().item())
#     loss_images.append(loss_image.cpu().item())
   
#     # エポックごとのロスの表示
#     print(f"Epoch {epoch+1}/{epochs}, Loss: {loss:.4f}, loss_vec: {loss_vec:.4f}, loss_image: {loss_image:.4f}, Shift Range: ±{shift_range} pixels")

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
epochs_range = range(1, epoch + 1)  # `epoch + 2` を `epoch + 1` に変更

# 損失、MSE、勾配をプロット
epochs_range = range(1,  epoch+2)

plt.figure(figsize=(12, 8))
plt.plot(epochs_range, losses, label='Loss')
plt.plot(epochs_range, loss_vecs, label='loss_vecs')
plt.plot(epochs_range, loss_images, label='loss_images')
# plt.plot(epochs_range, loss_hightVecs, label='loss_hightVecs')

plt.xlabel('Epochs')
plt.ylabel('Value')
plt.title('Training Metrics')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# model3D_7 = vxm.networks.VxmDense((64, 128, 128), nb_features, int_steps=0)
# model3D_7.to(device)
# optimizer = optim.Adam(model3D_7.parameters(), lr=1e-4)

# 学習済みモデルが既にある場合
model3D_3.load_state_dict(torch.load('model_VXM_3D_duwl_omomi_NodecoderHH.pth', map_location=device))

CT1 = np.load('No13_CT1_256_256_128.npz')['Train']
CT1 = np.transpose(CT1, (3, 0, 1, 2))
print('CT1_shape:', CT1.shape)
CT2 = np.load('No13_CT2_256_256_128.npz')['Train']
CT2 = np.transpose(CT2, (3, 0, 1, 2))
print('CT2_shape:', CT2.shape)

x_val_1 = CT1[0, :, :, :]
x_val_1 = x_val_1[np.newaxis, ..., np.newaxis]
x_val_2 = CT2[0, :, :, :]
x_val_2 = x_val_2[np.newaxis, ..., np.newaxis]

batch_size = 2

idx1 = np.random.randint(0, x_val_1.shape[0], size=batch_size)
moving_images = x_val_1[idx1]
moving_images = torch.tensor(moving_images).permute(0, 4, 1, 2, 3).float()
moving_images11 = moving_images.permute(0, 1, 2, 3, 4)
print(moving_images11.shape)

idx2 = np.random.randint(0, x_val_2.shape[0], size=batch_size)
fixed_images = x_val_2[idx2]
fixed_images = torch.tensor(fixed_images).permute(0, 4, 1, 2, 3).float()
fixed_images11 = fixed_images.permute(0, 1, 2, 3, 4)
print(fixed_images11.shape)

# 検証データを使って予測を行う
model3D_7 = model3D_3
model3D_7.eval()  # モデルを評価モードにする
with torch.no_grad():  # 勾配計算を無効化

    moving_images = fixed_images11
    fixed_images = moving_images11

    moving_images = torch.nn.functional.interpolate(moving_images, size=(64, 128, 128), mode='trilinear', align_corners=False)
    fixed_images = torch.nn.functional.interpolate(fixed_images, size=(64, 128, 128), mode='trilinear', align_corners=False)

    moving_images = moving_images.to(device)
    fixed_images = fixed_images.to(device)    

    # moving_images2 = transformer(moving_images, displacement_field)
    
    # transformed_image, Vec, Vec_HH, moving_image_HH= model3D_3(moving_images, fixed_images)
    transformed_image, Vec = model3D_3(moving_images, fixed_images)

    
# バッチから最初の画像を取得
moving_image = moving_images[0].cpu().numpy()
fixed_image = fixed_images[0].cpu().numpy()
transformed_image = transformed_image[0].cpu().numpy()
vector_field11 = Vec[0].cpu().numpy()
# Out:
# CT1_shape: (1, 128, 256, 256)
# CT2_shape: (1, 128, 256, 256)
# torch.Size([2, 1, 128, 256, 256])
# torch.Size([2, 1, 128, 256, 256])
# LL_Moving tensor(0.2551, device='cuda:0')
# HH_Moving tensor(0.0107, device='cuda:0')
# LL_Fixed tensor(0.2266, device='cuda:0')
# HH_Fixed tensor(0.0095, device='cuda:0')
# torch.Size([2, 3, 64, 128, 128])
# torch.Size([2, 1, 64, 128, 128])

# %%
import numpy as np
import torch
from tifffile import imsave
plt.figure(figsize=(18, 6))  # 図のサイズを大きくする

i = 35

# moving_imageの表示32￥
plt.subplot(131)
A = moving_image[0, i, :, :]
plt.imshow(A, cmap='gray', extent=[0, 128, 0, 128])  # extentで表示範囲を指定
plt.title('moving_image Plane')
plt.colorbar()

# fixed_imageの表示
plt.subplot(132)
B = fixed_image[0, i, :, :]
plt.imshow(B, cmap='gray', extent=[0, 128, 0, 128])  # extentで表示範囲を指定
plt.title('fixed_image Plane')
plt.colorbar()
    
# transformed_imageの表示
plt.subplot(133)
C = transformed_image[0, i, :, :]
plt.imshow(C, cmap='gray', extent=[0, 128, 0, 128])  # extentで表示範囲を指定
plt.title('transformed_image Plane')
plt.colorbar()
    
plt.tight_layout()
plt.show()

# %%
import numpy as np
import torch
from tifffile import imsave
plt.figure(figsize=(18, 6))  # 図のサイズを大きくする

i = 33

# moving_imageの表示32￥
plt.subplot(131)
A = moving_image[0, i, :, :]
plt.imshow(A, cmap='gray', extent=[0, 128, 0, 128])  # extentで表示範囲を指定
plt.title('moving_image Plane')
plt.colorbar()

# fixed_imageの表示
plt.subplot(132)
B = fixed_image[0, i, :, :]
plt.imshow(B, cmap='gray', extent=[0, 128, 0, 128])  # extentで表示範囲を指定
plt.title('fixed_image Plane')
plt.colorbar()
    
# transformed_imageの表示
plt.subplot(133)
C = transformed_image[0, i, :, :]
plt.imshow(C, cmap='gray', extent=[0, 128, 0, 128])  # extentで表示範囲を指定
plt.title('transformed_image Plane')
plt.colorbar()
    
plt.tight_layout()
plt.show()

# %%
def dice_coefficient(img1, img2):
    intersection = np.logical_and(img1, img2)
    return 2.0 * intersection.sum() / (img1.sum() + img2.sum())

def jaccard_coefficient(img1, img2):
    intersection = np.logical_and(img1, img2)
    union = np.logical_or(img1, img2)
    return intersection.sum() / union.sum()

# 画像を2値化（任意のしきい値でしきい値処理を行う）
threshold = 0.2  # しきい値（任意の値を設定してください）
fixed_image_bin = (fixed_image > threshold).astype(int)
transformed_image_bin = (transformed_image > threshold).astype(int)

# Dice係数とJaccard係数を計算
dice = dice_coefficient(fixed_image_bin, transformed_image_bin)
print(f"Dice係数: {dice}")
jaccard = jaccard_coefficient(fixed_image_bin, transformed_image_bin)
print(f"Jaccard係数: {jaccard}")

# %%
# imsave('moving_image_Tu.tif', A)
# imsave('fixed_image_Tu.tif', B)
# imsave('transformed_image_Tu.tif', C)
