# %%
import pybamm

model = pybamm.lithium_ion.DFN({
    "SEI": "solvent-diffusion limited",
    "SEI on cracks": "true",
    "lithium plating": "partially reversible",
    "lithium plating porosity change": "true",
})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 3
#       1 import pybamm
# ----> 3 model = pybamm.lithium_ion.DFN({
#       4     "SEI": "solvent-diffusion limited",
#       5     "SEI on cracks": "true",
#       6     "lithium plating": "partially reversible",
#       7     "lithium plating porosity change": "true",
#       8 })
#
# File ~\anaconda3\envs\nn\lib\site-packages\pybamm\models\full_battery_models\lithium_ion\dfn.py:26, in DFN.__init__(self, options, name, build)
#      23 def __init__(self, options=None, name="Doyle-Fuller-Newman model", build=True):
#      24     # For degradation models we use the full form since this is a full-order model
#      25     self.x_average = False
# ---> 26     super().__init__(options, name)
#      28     self.set_submodels(build)
#      30     pybamm.citations.register("Doyle1993")
#
# File ~\anaconda3\envs\nn\lib\site-packages\pybamm\models\full_battery_models\lithium_ion\base_lithium_ion_model.py:32, in BaseModel.__init__(self, options, name, build)
#      30 def __init__(self, options=None, name="Unnamed lithium-ion model", build=False):
#      31     super().__init__(options, name)
# ---> 32     self.param = pybamm.LithiumIonParameters(self.options)
#      34     self.set_standard_output_variables()
#      36     # Li models should calculate esoh by default
#
# File ~\anaconda3\envs\nn\lib\site-packages\pybamm\parameters\lithium_ion_parameters.py:40, in LithiumIonParameters.__init__(self, options)
#      33 self.domain_params = {
#      34     "negative": self.n,
#      35     "separator": self.s,
#      36     "positive": self.p,
#      37 }
#      39 # Set parameters
# ---> 40 self._set_parameters()
#
# File ~\anaconda3\envs\nn\lib\site-packages\pybamm\parameters\lithium_ion_parameters.py:98, in LithiumIonParameters._set_parameters(self)
#      96 # Domain parameters
#      97 for domain in self.domain_params.values():
# ---> 98     domain._set_parameters()
#     100 # Electrolyte properties
#     101 self.epsilon_init = pybamm.concatenation(
#     102     *[
#     103         self.domain_params[domain.split()[0]].epsilon_init
#     104         for domain in self.options.whole_cell_domains
#     105     ]
#     106 )
#
# File ~\anaconda3\envs\nn\lib\site-packages\pybamm\parameters\lithium_ion_parameters.py:269, in DomainLithiumIonParameters._set_parameters(self)
#     266 self.L_cc = self.geo.L_cc
#     268 for phase in self.phase_params.values():
# --> 269     phase._set_parameters()
#     271 # Tab geometry (for pouch cells)
#     272 self.L_tab = self.geo.L_tab
#
# File ~\anaconda3\envs\nn\lib\site-packages\pybamm\parameters\lithium_ion_parameters.py:471, in ParticleLithiumIonParameters._set_parameters(self)
#     462 # Particle properties
#     463 self.epsilon_s = pybamm.FunctionParameter(
#     464     f"{pref}{Domain} electrode active material volume fraction",
#     465     {
#    (...)
#     469     },
#     470 )
# --> 471 self.epsilon_s_av = pybamm.xyz_average(self.epsilon_s)
#     472 self.c_max = pybamm.Parameter(
#     473     f"{pref}Maximum concentration in {domain} electrode [mol.m-3]"
#     474 )
#     475 if self.options["open-circuit potential"] == "MSMR":
#
# File ~\anaconda3\envs\nn\lib\site-packages\pybamm\expression_tree\averages.py:308, in xyz_average(symbol)
#     307 def xyz_average(symbol: pybamm.Symbol) -> pybamm.Symbol:
# --> 308     return yz_average(x_average(symbol))
#
# File ~\anaconda3\envs\nn\lib\site-packages\pybamm\expression_tree\averages.py:304, in yz_average(symbol)
#     301     return _sum_of_averages(symbol, yz_average)
#     302 # Otherwise, define a YZAverage
#     303 else:
# --> 304     return YZAverage(symbol)
#
# File ~\anaconda3\envs\nn\lib\site-packages\pybamm\expression_tree\averages.py:61, in YZAverage.__init__(self, child)
#      60 def __init__(self, child: pybamm.Symbol) -> None:
# ---> 61     y = pybamm.standard_spatial_vars.y
#      62     z = pybamm.standard_spatial_vars.z
#      63     integration_variable: list[pybamm.IndependentVariable] = [y, z]
#
# AttributeError: module 'pybamm' has no attribute 'standard_spatial_vars'

# %%
import pybamm
print(pybamm.__version__)
# Out:
# PyBaMM can collect usage data and send it to the PyBaMM team to help us improve the software.
# We do not collect any sensitive information such as models, parameters, or simulation results - only information on which parts of the code are being used and how frequently.
# This is entirely optional and does not impact the functionality of PyBaMM.
# For more information, see https://docs.pybamm.org/en/latest/source/user_guide/index.html#telemetry
#
# Timeout reached. Defaulting to not enabling telemetry.
# 25.12.2
# Do you want to enable telemetry? (Y/n):  y
